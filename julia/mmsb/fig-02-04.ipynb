# %% [markdown]
# # Fig 2.04 Exponential decay

# %%
using Plots
Plots.gr(fmt=:png, lw=2)
# Out:
# Plots.GRBackend()

# %%
plot([t-> 3 * exp(-t) t->3 * exp(-2t) t-> 3 * exp(-3t)], 0.0, 5.0, 
     xlim = (0, 5), ylim=(0, 3.2), xlabel="Time", ylabel="Concentration", 
     label = ["exp(-t)" "exp(-2t)" "exp(-3t)"], title= "Figure 2.4")
